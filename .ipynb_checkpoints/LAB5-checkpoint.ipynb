# %%
#Libraries
import numpy as np
import matplotlib.pyplot as plt 
from collections import Counter

# Generate random data
data = np.random.rand(100)
labels = ["Class1" if x <= 0.5 else "Class2" for x in data[:50]]

# Function to compute Euclidean distance
def euclidean_distance(x1, x2):
    return abs(x1 - x2)

# k-NN classifier function
def knn_classifier(train_data, train_labels, test_point, k):
    distances = [(euclidean_distance(test_point, train_data[i]), train_labels[i]) for i in range(len(train_data))]
    
    # Sort by distance
    distances.sort(key=lambda x: x[0])
    
    # Get k nearest neighbors
    k_nearest_neighbors = distances[:k]
    
    # Extract the labels 
    k_nearest_labels = [label for _, label in k_nearest_neighbors]
    
    # Return the most common label
    return Counter(k_nearest_labels).most_common(1)[0][0]

# Prepare the training and test data
# First 50 points for training
train_data = data[:50]

# Corresponding labels for training
train_labels = labels

# Remaining 50 points for testing
test_data = data[50:]

# Values of k to test
k_values = [1, 2, 3, 4, 5, 20, 30]

print("--- k-Nearest Neighbors Classification ---")
print("Training dataset: First 50 points labeled based on the rule (x <= 0.5 -> Class1, x > 0.5 -> Class2)")
print("Testing dataset: Remaining 50 points to be classified\n")

# Store the results for each k value 
results = {}

# Loop over different values of k
for k in k_values:
    print(f"Results for k = {k}:")
    classified_labels = [knn_classifier(train_data, train_labels, test_point, k) for test_point in test_data]
    results[k] = classified_labels
    
    # Output the classification results
    for i, label in enumerate(classified_labels, start=51):
        print(f"Point x{i} (value: {test_data[i - 51]:.4f}) is classified as {label}") 
    print("\n")

print("Classification complete.\n")

# Visualize the classification results for each k value
for k in k_values:
    classified_labels = results[k]
    
    class1_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class1"]
    class2_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class2"]
    
    plt.figure(figsize=(10, 6))
    plt.scatter(train_data, [0] * len(train_data), 
                c=["blue" if label == "Class1" else "red" for label in train_labels],
                label="Training Data", marker="o")
    
    plt.scatter(class1_points, [1] * len(class1_points), c="blue", label="Class1 (Test)", marker="x")
    plt.scatter(class2_points, [1] * len(class2_points), c="red", label="Class2 (Test)", marker="x")
    
    plt.title(f"k-NN Classification Results for k = {k}")
    plt.xlabel("Data Points")
    plt.ylabel("Classification Level")
    plt.legend()
    plt.grid(True) 
    plt.show()
# Out:
# --- k-Nearest Neighbors Classification ---
# Training dataset: First 50 points labeled based on the rule (x <= 0.5 -> Class1, x > 0.5 -> Class2)
# Testing dataset: Remaining 50 points to be classified
#
# Results for k = 1:
# Point x51 (value: 0.1698) is classified as Class1
# Point x52 (value: 0.5655) is classified as Class2
# Point x53 (value: 0.7626) is classified as Class2
# Point x54 (value: 0.8586) is classified as Class2
# Point x55 (value: 0.8018) is classified as Class2
# Point x56 (value: 0.9593) is classified as Class2
# Point x57 (value: 0.0815) is classified as Class1
# Point x58 (value: 0.6245) is classified as Class2
# Point x59 (value: 0.7678) is classified as Class2
# Point x60 (value: 0.8844) is classified as Class2
# Point x61 (value: 0.8757) is classified as Class2
# Point x62 (value: 0.1140) is classified as Class1
# Point x63 (value: 0.0743) is classified as Class1
# Point x64 (value: 0.8981) is classified as Class2
# Point x65 (value: 0.3775) is classified as Class1
# Point x66 (value: 0.6637) is classified as Class2
# Point x67 (value: 0.6122) is classified as Class2
# Point x68 (value: 0.0005) is classified as Class1
# Point x69 (value: 0.8987) is classified as Class2
# Point x70 (value: 0.3582) is classified as Class1
# Point x71 (value: 0.3644) is classified as Class1
# Point x72 (value: 0.6699) is classified as Class2
# Point x73 (value: 0.3251) is classified as Class1
# Point x74 (value: 0.3657) is classified as Class1
# Point x75 (value: 0.6922) is classified as Class2
# Point x76 (value: 0.3990) is classified as Class1
# Point x77 (value: 0.3972) is classified as Class1
# Point x78 (value: 0.1531) is classified as Class1
# Point x79 (value: 0.7612) is classified as Class2
# Point x80 (value: 0.8868) is classified as Class2
# Point x81 (value: 0.8033) is classified as Class2
# Point x82 (value: 0.2653) is classified as Class1
# Point x83 (value: 0.8622) is classified as Class2
# Point x84 (value: 0.5394) is classified as Class2
# Point x85 (value: 0.7434) is classified as Class2
# Point x86 (value: 0.6875) is classified as Class2
# Point x87 (value: 0.8450) is classified as Class2
# Point x88 (value: 0.0852) is classified as Class1
# Point x89 (value: 0.8837) is classified as Class2
# Point x90 (value: 0.4062) is classified as Class1
# Point x91 (value: 0.5916) is classified as Class2
# Point x92 (value: 0.6227) is classified as Class2
# Point x93 (value: 0.2004) is classified as Class1
# Point x94 (value: 0.4595) is classified as Class1
# Point x95 (value: 0.2651) is classified as Class1
# Point x96 (value: 0.7368) is classified as Class2
# Point x97 (value: 0.2930) is classified as Class1
# Point x98 (value: 0.5122) is classified as Class2
# Point x99 (value: 0.3053) is classified as Class1
# Point x100 (value: 0.1197) is classified as Class1
#
#
# Results for k = 2:
# Point x51 (value: 0.1698) is classified as Class1
# Point x52 (value: 0.5655) is classified as Class2
# Point x53 (value: 0.7626) is classified as Class2
# Point x54 (value: 0.8586) is classified as Class2
# Point x55 (value: 0.8018) is classified as Class2
# Point x56 (value: 0.9593) is classified as Class2
# Point x57 (value: 0.0815) is classified as Class1
# Point x58 (value: 0.6245) is classified as Class2
# Point x59 (value: 0.7678) is classified as Class2
# Point x60 (value: 0.8844) is classified as Class2
# Point x61 (value: 0.8757) is classified as Class2
# Point x62 (value: 0.1140) is classified as Class1
# Point x63 (value: 0.0743) is classified as Class1
# Point x64 (value: 0.8981) is classified as Class2
# Point x65 (value: 0.3775) is classified as Class1
# Point x66 (value: 0.6637) is classified as Class2
# Point x67 (value: 0.6122) is classified as Class2
# Point x68 (value: 0.0005) is classified as Class1
# Point x69 (value: 0.8987) is classified as Class2
# Point x70 (value: 0.3582) is classified as Class1
# Point x71 (value: 0.3644) is classified as Class1
# Point x72 (value: 0.6699) is classified as Class2
# Point x73 (value: 0.3251) is classified as Class1
# Point x74 (value: 0.3657) is classified as Class1
# Point x75 (value: 0.6922) is classified as Class2
# Point x76 (value: 0.3990) is classified as Class1
# Point x77 (value: 0.3972) is classified as Class1
# Point x78 (value: 0.1531) is classified as Class1
# Point x79 (value: 0.7612) is classified as Class2
# Point x80 (value: 0.8868) is classified as Class2
# Point x81 (value: 0.8033) is classified as Class2
# Point x82 (value: 0.2653) is classified as Class1
# Point x83 (value: 0.8622) is classified as Class2
# Point x84 (value: 0.5394) is classified as Class2
# Point x85 (value: 0.7434) is classified as Class2
# Point x86 (value: 0.6875) is classified as Class2
# Point x87 (value: 0.8450) is classified as Class2
# Point x88 (value: 0.0852) is classified as Class1
# Point x89 (value: 0.8837) is classified as Class2
# Point x90 (value: 0.4062) is classified as Class1
# Point x91 (value: 0.5916) is classified as Class2
# Point x92 (value: 0.6227) is classified as Class2
# Point x93 (value: 0.2004) is classified as Class1
# Point x94 (value: 0.4595) is classified as Class1
# Point x95 (value: 0.2651) is classified as Class1
# Point x96 (value: 0.7368) is classified as Class2
# Point x97 (value: 0.2930) is classified as Class1
# Point x98 (value: 0.5122) is classified as Class2
# Point x99 (value: 0.3053) is classified as Class1
# Point x100 (value: 0.1197) is classified as Class1
#
#
# Results for k = 3:
# Point x51 (value: 0.1698) is classified as Class1
# Point x52 (value: 0.5655) is classified as Class2
# Point x53 (value: 0.7626) is classified as Class2
# Point x54 (value: 0.8586) is classified as Class2
# Point x55 (value: 0.8018) is classified as Class2
# Point x56 (value: 0.9593) is classified as Class2
# Point x57 (value: 0.0815) is classified as Class1
# Point x58 (value: 0.6245) is classified as Class2
# Point x59 (value: 0.7678) is classified as Class2
# Point x60 (value: 0.8844) is classified as Class2
# Point x61 (value: 0.8757) is classified as Class2
# Point x62 (value: 0.1140) is classified as Class1
# Point x63 (value: 0.0743) is classified as Class1
# Point x64 (value: 0.8981) is classified as Class2
# Point x65 (value: 0.3775) is classified as Class1
# Point x66 (value: 0.6637) is classified as Class2
# Point x67 (value: 0.6122) is classified as Class2
# Point x68 (value: 0.0005) is classified as Class1
# Point x69 (value: 0.8987) is classified as Class2
# Point x70 (value: 0.3582) is classified as Class1
# Point x71 (value: 0.3644) is classified as Class1
# Point x72 (value: 0.6699) is classified as Class2
# Point x73 (value: 0.3251) is classified as Class1
# Point x74 (value: 0.3657) is classified as Class1
# Point x75 (value: 0.6922) is classified as Class2
# Point x76 (value: 0.3990) is classified as Class1
# Point x77 (value: 0.3972) is classified as Class1
# Point x78 (value: 0.1531) is classified as Class1
# Point x79 (value: 0.7612) is classified as Class2
# Point x80 (value: 0.8868) is classified as Class2
# Point x81 (value: 0.8033) is classified as Class2
# Point x82 (value: 0.2653) is classified as Class1
# Point x83 (value: 0.8622) is classified as Class2
# Point x84 (value: 0.5394) is classified as Class2
# Point x85 (value: 0.7434) is classified as Class2
# Point x86 (value: 0.6875) is classified as Class2
# Point x87 (value: 0.8450) is classified as Class2
# Point x88 (value: 0.0852) is classified as Class1
# Point x89 (value: 0.8837) is classified as Class2
# Point x90 (value: 0.4062) is classified as Class1
# Point x91 (value: 0.5916) is classified as Class2
# Point x92 (value: 0.6227) is classified as Class2
# Point x93 (value: 0.2004) is classified as Class1
# Point x94 (value: 0.4595) is classified as Class1
# Point x95 (value: 0.2651) is classified as Class1
# Point x96 (value: 0.7368) is classified as Class2
# Point x97 (value: 0.2930) is classified as Class1
# Point x98 (value: 0.5122) is classified as Class2
# Point x99 (value: 0.3053) is classified as Class1
# Point x100 (value: 0.1197) is classified as Class1
#
#
# Results for k = 4:
# Point x51 (value: 0.1698) is classified as Class1
# Point x52 (value: 0.5655) is classified as Class2
# Point x53 (value: 0.7626) is classified as Class2
# Point x54 (value: 0.8586) is classified as Class2
# Point x55 (value: 0.8018) is classified as Class2
# Point x56 (value: 0.9593) is classified as Class2
# Point x57 (value: 0.0815) is classified as Class1
# Point x58 (value: 0.6245) is classified as Class2
# Point x59 (value: 0.7678) is classified as Class2
# Point x60 (value: 0.8844) is classified as Class2
# Point x61 (value: 0.8757) is classified as Class2
# Point x62 (value: 0.1140) is classified as Class1
# Point x63 (value: 0.0743) is classified as Class1
# Point x64 (value: 0.8981) is classified as Class2
# Point x65 (value: 0.3775) is classified as Class1
# Point x66 (value: 0.6637) is classified as Class2
# Point x67 (value: 0.6122) is classified as Class2
# Point x68 (value: 0.0005) is classified as Class1
# Point x69 (value: 0.8987) is classified as Class2
# Point x70 (value: 0.3582) is classified as Class1
# Point x71 (value: 0.3644) is classified as Class1
# Point x72 (value: 0.6699) is classified as Class2
# Point x73 (value: 0.3251) is classified as Class1
# Point x74 (value: 0.3657) is classified as Class1
# Point x75 (value: 0.6922) is classified as Class2
# Point x76 (value: 0.3990) is classified as Class1
# Point x77 (value: 0.3972) is classified as Class1
# Point x78 (value: 0.1531) is classified as Class1
# Point x79 (value: 0.7612) is classified as Class2
# Point x80 (value: 0.8868) is classified as Class2
# Point x81 (value: 0.8033) is classified as Class2
# Point x82 (value: 0.2653) is classified as Class1
# Point x83 (value: 0.8622) is classified as Class2
# Point x84 (value: 0.5394) is classified as Class2
# Point x85 (value: 0.7434) is classified as Class2
# Point x86 (value: 0.6875) is classified as Class2
# Point x87 (value: 0.8450) is classified as Class2
# Point x88 (value: 0.0852) is classified as Class1
# Point x89 (value: 0.8837) is classified as Class2
# Point x90 (value: 0.4062) is classified as Class1
# Point x91 (value: 0.5916) is classified as Class2
# Point x92 (value: 0.6227) is classified as Class2
# Point x93 (value: 0.2004) is classified as Class1
# Point x94 (value: 0.4595) is classified as Class1
# Point x95 (value: 0.2651) is classified as Class1
# Point x96 (value: 0.7368) is classified as Class2
# Point x97 (value: 0.2930) is classified as Class1
# Point x98 (value: 0.5122) is classified as Class2
# Point x99 (value: 0.3053) is classified as Class1
# Point x100 (value: 0.1197) is classified as Class1
#
#
# Results for k = 5:
# Point x51 (value: 0.1698) is classified as Class1
# Point x52 (value: 0.5655) is classified as Class2
# Point x53 (value: 0.7626) is classified as Class2
# Point x54 (value: 0.8586) is classified as Class2
# Point x55 (value: 0.8018) is classified as Class2
# Point x56 (value: 0.9593) is classified as Class2
# Point x57 (value: 0.0815) is classified as Class1
# Point x58 (value: 0.6245) is classified as Class2
# Point x59 (value: 0.7678) is classified as Class2
# Point x60 (value: 0.8844) is classified as Class2
# Point x61 (value: 0.8757) is classified as Class2
# Point x62 (value: 0.1140) is classified as Class1
# Point x63 (value: 0.0743) is classified as Class1
# Point x64 (value: 0.8981) is classified as Class2
# Point x65 (value: 0.3775) is classified as Class1
# Point x66 (value: 0.6637) is classified as Class2
# Point x67 (value: 0.6122) is classified as Class2
# Point x68 (value: 0.0005) is classified as Class1
# Point x69 (value: 0.8987) is classified as Class2
# Point x70 (value: 0.3582) is classified as Class1
# Point x71 (value: 0.3644) is classified as Class1
# Point x72 (value: 0.6699) is classified as Class2
# Point x73 (value: 0.3251) is classified as Class1
# Point x74 (value: 0.3657) is classified as Class1
# Point x75 (value: 0.6922) is classified as Class2
# Point x76 (value: 0.3990) is classified as Class1
# Point x77 (value: 0.3972) is classified as Class1
# Point x78 (value: 0.1531) is classified as Class1
# Point x79 (value: 0.7612) is classified as Class2
# Point x80 (value: 0.8868) is classified as Class2
# Point x81 (value: 0.8033) is classified as Class2
# Point x82 (value: 0.2653) is classified as Class1
# Point x83 (value: 0.8622) is classified as Class2
# Point x84 (value: 0.5394) is classified as Class2
# Point x85 (value: 0.7434) is classified as Class2
# Point x86 (value: 0.6875) is classified as Class2
# Point x87 (value: 0.8450) is classified as Class2
# Point x88 (value: 0.0852) is classified as Class1
# Point x89 (value: 0.8837) is classified as Class2
# Point x90 (value: 0.4062) is classified as Class1
# Point x91 (value: 0.5916) is classified as Class2
# Point x92 (value: 0.6227) is classified as Class2
# Point x93 (value: 0.2004) is classified as Class1
# Point x94 (value: 0.4595) is classified as Class1
# Point x95 (value: 0.2651) is classified as Class1
# Point x96 (value: 0.7368) is classified as Class2
# Point x97 (value: 0.2930) is classified as Class1
# Point x98 (value: 0.5122) is classified as Class2
# Point x99 (value: 0.3053) is classified as Class1
# Point x100 (value: 0.1197) is classified as Class1
#
#
# Results for k = 20:
# Point x51 (value: 0.1698) is classified as Class1
# Point x52 (value: 0.5655) is classified as Class2
# Point x53 (value: 0.7626) is classified as Class2
# Point x54 (value: 0.8586) is classified as Class2
# Point x55 (value: 0.8018) is classified as Class2
# Point x56 (value: 0.9593) is classified as Class2
# Point x57 (value: 0.0815) is classified as Class1
# Point x58 (value: 0.6245) is classified as Class2
# Point x59 (value: 0.7678) is classified as Class2
# Point x60 (value: 0.8844) is classified as Class2
# Point x61 (value: 0.8757) is classified as Class2
# Point x62 (value: 0.1140) is classified as Class1
# Point x63 (value: 0.0743) is classified as Class1
# Point x64 (value: 0.8981) is classified as Class2
# Point x65 (value: 0.3775) is classified as Class1
# Point x66 (value: 0.6637) is classified as Class2
# Point x67 (value: 0.6122) is classified as Class2
# Point x68 (value: 0.0005) is classified as Class1
# Point x69 (value: 0.8987) is classified as Class2
# Point x70 (value: 0.3582) is classified as Class1
# Point x71 (value: 0.3644) is classified as Class1
# Point x72 (value: 0.6699) is classified as Class2
# Point x73 (value: 0.3251) is classified as Class1
# Point x74 (value: 0.3657) is classified as Class1
# Point x75 (value: 0.6922) is classified as Class2
# Point x76 (value: 0.3990) is classified as Class1
# Point x77 (value: 0.3972) is classified as Class1
# Point x78 (value: 0.1531) is classified as Class1
# Point x79 (value: 0.7612) is classified as Class2
# Point x80 (value: 0.8868) is classified as Class2
# Point x81 (value: 0.8033) is classified as Class2
# Point x82 (value: 0.2653) is classified as Class1
# Point x83 (value: 0.8622) is classified as Class2
# Point x84 (value: 0.5394) is classified as Class2
# Point x85 (value: 0.7434) is classified as Class2
# Point x86 (value: 0.6875) is classified as Class2
# Point x87 (value: 0.8450) is classified as Class2
# Point x88 (value: 0.0852) is classified as Class1
# Point x89 (value: 0.8837) is classified as Class2
# Point x90 (value: 0.4062) is classified as Class1
# Point x91 (value: 0.5916) is classified as Class2
# Point x92 (value: 0.6227) is classified as Class2
# Point x93 (value: 0.2004) is classified as Class1
# Point x94 (value: 0.4595) is classified as Class1
# Point x95 (value: 0.2651) is classified as Class1
# Point x96 (value: 0.7368) is classified as Class2
# Point x97 (value: 0.2930) is classified as Class1
# Point x98 (value: 0.5122) is classified as Class1
# Point x99 (value: 0.3053) is classified as Class1
# Point x100 (value: 0.1197) is classified as Class1
#
#
# Results for k = 30:
# Point x51 (value: 0.1698) is classified as Class1
# Point x52 (value: 0.5655) is classified as Class2
# Point x53 (value: 0.7626) is classified as Class2
# Point x54 (value: 0.8586) is classified as Class2
# Point x55 (value: 0.8018) is classified as Class2
# Point x56 (value: 0.9593) is classified as Class2
# Point x57 (value: 0.0815) is classified as Class1
# Point x58 (value: 0.6245) is classified as Class2
# Point x59 (value: 0.7678) is classified as Class2
# Point x60 (value: 0.8844) is classified as Class2
# Point x61 (value: 0.8757) is classified as Class2
# Point x62 (value: 0.1140) is classified as Class1
# Point x63 (value: 0.0743) is classified as Class1
# Point x64 (value: 0.8981) is classified as Class2
# Point x65 (value: 0.3775) is classified as Class1
# Point x66 (value: 0.6637) is classified as Class2
# Point x67 (value: 0.6122) is classified as Class2
# Point x68 (value: 0.0005) is classified as Class1
# Point x69 (value: 0.8987) is classified as Class2
# Point x70 (value: 0.3582) is classified as Class1
# Point x71 (value: 0.3644) is classified as Class1
# Point x72 (value: 0.6699) is classified as Class2
# Point x73 (value: 0.3251) is classified as Class1
# Point x74 (value: 0.3657) is classified as Class1
# Point x75 (value: 0.6922) is classified as Class2
# Point x76 (value: 0.3990) is classified as Class1
# Point x77 (value: 0.3972) is classified as Class1
# Point x78 (value: 0.1531) is classified as Class1
# Point x79 (value: 0.7612) is classified as Class2
# Point x80 (value: 0.8868) is classified as Class2
# Point x81 (value: 0.8033) is classified as Class2
# Point x82 (value: 0.2653) is classified as Class1
# Point x83 (value: 0.8622) is classified as Class2
# Point x84 (value: 0.5394) is classified as Class2
# Point x85 (value: 0.7434) is classified as Class2
# Point x86 (value: 0.6875) is classified as Class2
# Point x87 (value: 0.8450) is classified as Class2
# Point x88 (value: 0.0852) is classified as Class1
# Point x89 (value: 0.8837) is classified as Class2
# Point x90 (value: 0.4062) is classified as Class1
# Point x91 (value: 0.5916) is classified as Class2
# Point x92 (value: 0.6227) is classified as Class2
# Point x93 (value: 0.2004) is classified as Class1
# Point x94 (value: 0.4595) is classified as Class1
# Point x95 (value: 0.2651) is classified as Class1
# Point x96 (value: 0.7368) is classified as Class2
# Point x97 (value: 0.2930) is classified as Class1
# Point x98 (value: 0.5122) is classified as Class2
# Point x99 (value: 0.3053) is classified as Class1
# Point x100 (value: 0.1197) is classified as Class1
#
#
# Classification complete.
